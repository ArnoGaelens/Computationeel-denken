# %%
from PIL import Image
import numpy as np

breedte = int(input(f'Geef de breedte in:'))
hoogte = breedte//2   	    #int(input(f'Geef de hoogte in:'))



r_out = np.zeros((hoogte, breedte))
g_out = np.zeros((hoogte, breedte))
b_out = np.zeros((hoogte, breedte))

#Matrix bewerkingen komen hier:

for i in range(hoogte):
    for j in range(breedte):
        r_out[i][j] = 255
        g_out[i][j] = 255
        b_out[i][j] = 255

        if i < (1/3)*hoogte:
            r_out[i][j] = 0
            g_out[i][j] = 255
            b_out[i][j] = 0

        if i > (2/3)*hoogte:
            r_out[i][j] = 255
            g_out[i][j] = 0
            b_out[i][j] = 0

        if j < i and i < (1/3)*hoogte:
            r_out[i][j] = 0
            g_out[i][j] = 0
            b_out[i][j] = 0

        if j < hoogte - i and i > (1/3)*hoogte and j < hoogte//3:
            r_out[i][j] = 0
            g_out[i][j] = 0
            b_out[i][j] = 0

        

# converteer drie matrices terug naar een afbeelding
r_image_out = Image.fromarray(np.uint8(r_out))
g_image_out = Image.fromarray(np.uint8(g_out))
b_image_out = Image.fromarray(np.uint8(b_out))
output_im = Image.merge("RGB", (r_image_out, g_image_out, b_image_out))
output_im.show()

# %%
from PIL import Image
import numpy as np

breedte = int(input(f'Geef de breedte in:'))
hoogte = breedte//2   	    #int(input(f'Geef de hoogte in:'))



r_out = np.zeros((hoogte, breedte))
g_out = np.zeros((hoogte, breedte))
b_out = np.zeros((hoogte, breedte))

#Matrix bewerkingen komen hier:

for i in range(hoogte):
    for j in range(breedte):
        

        

# converteer drie matrices terug naar een afbeelding
r_image_out = Image.fromarray(np.uint8(r_out))
g_image_out = Image.fromarray(np.uint8(g_out))
b_image_out = Image.fromarray(np.uint8(b_out))
output_im = Image.merge("RGB", (r_image_out, g_image_out, b_image_out))
output_im.show()
